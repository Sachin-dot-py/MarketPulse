# %%
# Comprehensive dictionary of tags to tickers
tags_to_tickers = {
    # Political Tags
    "Trump": ["XOM", "CVX", "LMT", "BA"],
    "Biden": ["TSLA", "FSLR", "NEE", "PLUG"],
    "Climate Change": ["TSLA", "FSLR", "NEE", "RUN"],

    # Technology Tags
    "AI": ["MSFT", "NVDA", "GOOG", "META"],
    "Cloud Computing": ["AMZN", "MSFT", "GOOG", "ORCL"],
    "Semiconductors": ["NVDA", "AMD", "INTC", "TSM"],
    "Chips": ["NVDA", "AMD", "TSM", "QCOM"],
    "Cybersecurity": ["PANW", "FTNT", "CRWD", "ZS"],
    "Quantum Computing": ["IBM", "GOOG", "MSFT", "INTC"],
    "Digital Transformation": ["CRM", "NOW", "ADBE", "SNOW"],
    "Augmented Reality": ["AAPL", "MSFT", "META", "VUZI"],

    # Energy Tags
    "Oil": ["XOM", "CVX", "BP", "COP"],
    "Renewable Energy": ["FSLR", "NEE", "ENPH", "SEDG"],
    "Electric Vehicles": ["TSLA", "GM", "F", "RIVN"],
    "EV Batteries": ["QS", "TSLA", "ALB", "LTHM"],
    "Nuclear Energy": ["EXC", "DUK", "NEE", "SO"],
    "Hydrogen": ["PLUG", "BE", "BLDP", "NEL"],

    # Healthcare and Pharma
    "Pandemic": ["PFE", "MRNA", "JNJ", "BNTX"],
    "Healthcare": ["UNH", "ANTM", "CI", "HUM"],
    "Pharmaceuticals": ["PFE", "MRK", "LLY", "BMY"],
    "Biotech": ["AMGN", "BIIB", "REGN", "VRTX"],
    "Genomics": ["ILMN", "CRSP", "EDIT", "NTLA"],
    "Medical Devices": ["ISRG", "MDT", "BSX", "EW"],

    # Finance and Economy
    "Banking": ["JPM", "BAC", "C", "GS"],
    "Recession": ["SPY", "VOO", "GLD", "SLV"],
    "Inflation": ["GLD", "SLV", "TIP", "TBT"],
    "Federal Reserve": ["JPM", "GS", "WFC", "MS"],
    "Cryptocurrency": ["COIN", "MARA", "RIOT", "NVDA"],
    "Fintech": ["SQ", "PYPL", "AFRM", "SOFI"],

    # Retail and E-commerce
    "Retail": ["WMT", "TGT", "COST", "HD"],
    "E-commerce": ["AMZN", "EBAY", "ETSY", "SHOP"],
    "Luxury Goods": ["LVMUY", "TIF", "RACE", "EL"],
    "Consumer Discretionary": ["NKE", "SBUX", "MCD", "DIS"],
    "Apparel": ["GPS", "LEVI", "RL", "UAA"],

    # Social Media and Communication
    "Social Media": ["META", "TWTR", "SNAP", "PINS"],
    "Streaming": ["NFLX", "DIS", "ROKU", "WBD"],
    "Telecom": ["T", "VZ", "TMUS", "CHTR"],
    "Content Creation": ["ADBE", "CANVA", "DASH", "FVRR"],

    # Industrial and Logistics
    "Logistics": ["FDX", "UPS", "XPO", "CHRW"],
    "Defense": ["LMT", "NOC", "GD", "RTX"],
    "Aerospace": ["BA", "RTX", "LMT", "NOC"],
    "Infrastructure": ["CAT", "DE", "VMC", "MLM"],
    "Manufacturing": ["HON", "GE", "MMM", "ITW"],

    # Commodities
    "Gold": ["NEM", "GOLD", "AEM", "FNV"],
    "Silver": ["SLV", "PAAS", "WPM", "AG"],
    "Commodities": ["FCX", "RIO", "BHP", "AA"],
    "Lithium": ["ALB", "LTHM", "SQM", "PLL"],
    "Copper": ["FCX", "SCCO", "RIO", "BHP"],

    # People Tags
    "Elon Musk": ["TSLA", "SPCE", "TWTR", "NEURALINK"],
    "Jeff Bezos": ["AMZN", "BLUE ORIGIN"],
    "Bill Gates": ["MSFT", "BILL & MELINDA GATES FOUNDATION"],
    "Warren Buffett": ["BRK.A", "BRK.B"],
    "Mark Zuckerberg": ["META"],
    "Sundar Pichai": ["GOOG", "GOOGL"],
    "Tim Cook": ["AAPL"],

    # Global Events
    "War": ["LMT", "NOC", "RTX", "BA"],
    "Natural Disaster": ["PCG", "DUK", "NEE", "AWK"],
    "Inflation Policy": ["JPM", "GS", "BAC", "MS"],
    "Interest Rate Hike": ["JPM", "WFC", "C", "GS"],

    # Miscellaneous
    "Space": ["SPCE", "BA", "LMT", "RTX"],
    "Housing": ["Z", "RDFN", "LEN", "DHI"],
    "Consumer Goods": ["PG", "CL", "KMB", "CHD"],
    "Airlines": ["DAL", "AAL", "UAL", "LUV"],
    "Agriculture": ["ADM", "BG", "DE", "CTVA"],
    "Metaverse": ["META", "NVDA", "RBLX", "U"],
    "Artificial Intelligence": ["MSFT", "GOOG", "NVDA", "META"],
    "5G": ["VZ", "TMUS", "QCOM", "NOK"],
    "Clean Energy": ["FSLR", "PLUG", "ENPH", "SEDG"],
    "Cybersecurity": ["PANW", "CRWD", "FTNT", "ZS"],
    "Robotics": ["IRBT", "ISRG", "TER", "ROK"],
    "Autonomous Vehicles": ["TSLA", "GOOG", "NVDA", "APTIV"],
    "Quantum Computing": ["IBM", "GOOG", "MSFT", "IONQ"],
    "Digital Payments": ["PYPL", "SQ", "V", "MA"],
    "ESG": ["AAPL", "MSFT", "TSLA", "NEE"],
    "Industrial Automation": ["ROK", "ABB", "AMAT", "ETN"],
    "Food Delivery": ["UBER", "DASH", "GRUB", "WMT"],
    "Video Games": ["ATVI", "EA", "TTWO", "SONY"],
    "Pet Care": ["ZTS", "IDXX", "CHWY", "PETQ"],
    "Cannabis": ["CGC", "TLRY", "CRON", "ACB"],
    "Water": ["AWK", "WTRG", "XYL", "AQUA"],
    "Education": ["CHGG", "TWOU", "LRN", "COUR"],
    "Gaming": ["RBLX", "EA", "ATVI", "TTWO"],
    "Renewables": ["NEE", "FSLR", "ENPH", "SEDG"],
    "Electric Charging": ["CHPT", "BLNK", "TSLA", "SBE"],
    "Luxury Travel": ["ABNB", "MAR", "HLT", "EXPE"],
    "Digital Advertising": ["GOOG", "META", "TTD", "ROKU"],
}
